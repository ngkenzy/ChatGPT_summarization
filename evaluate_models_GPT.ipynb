# %% [markdown]
# # Evaluate Models
# Ask GPT to evaluate summaries from different models. Code can be extended to evaluate different attributes

# %%
# load dataset
# !pip install openpyxl
import pandas as pd

df = pd.read_excel('summaries_final.xlsx')
# df = pd.read_excel('scores.xlsx')

# %%
df
# Out:
#     index                                            article
# 0       0  LONDON, England (Reuters) -- Harry Potter star...  \
# 1       3  WASHINGTON (CNN) -- Doctors removed five small...
# 2       7  BOGOTA, Colombia (CNN) -- A key rebel commande...
# 3       9  (CNN) -- Police and FBI agents are investigati...
# 4      12  BREMEN, Germany -- Carlos Alberto, who scored ...
# 5      13  WASHINGTON (CNN) -- Vice President Dick Cheney...
# 6      14  SAN FRANCISCO, California (CNN)  -- A magnitud...
# 7      16  (CNN) -- At least 14 people were killed and 60...
# 8      17  (CNN) -- Football superstar, celebrity, fashio...
# 9      19  LONDON, England -- Savers at a leading UK mort...
# 10     21  LAGOS, Nigeria (Reuters) -- Nigeria's televisi...
# 11     23  LONDON, England -- Chelsea are waiting on the ...
# 12     26  ROME. Italy -- Italy and Roma striker Francesc...
# 13     27  WASHINGTON (CNN) -- Allegations that Blackwate...
# ...

# %%
MY_LAS_API_TOKEN = '0e99db9c1ab3724d3447a98f269465268a045e67b7f39e047ce40b946bc499d8'

# %%
import requests
import json
def evaluate(instructions, article, summary, answer, temp=0.70):
    url = "https://apiproxy.ncsu-las.net/APIGateway/openai/v1/chat/completions"

    headers = {
        "Content-Type": "application/json",
        "LAS-API-Token": MY_LAS_API_TOKEN
    }
    
    prompt = f"""{instructions}
    
    Article:
    {article}

    Summary:
    {summary}
    
    {answer}:
    """

    data = {
      "model": "gpt-3.5-turbo",
      "messages": [{"role": "user", "content": prompt}],
      "temperature": temp
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))
    try:
        score = response.json()["choices"][0]["message"]["content"]
    except:
        score = "No evaluation possible."
    return score

# %%
# results_df = pd.DataFrame()
# column_names = list(df.columns)

# instr = "Decide if the following summary is fair with the corresponding article. Note that fairness means the summary should not have a distinct tone or angle and should present the information in a neutral manner without any bias."
# answer = "Answer (yes or no)"
# for model in column_names[2:]:
#     gpt_eval = []
#     for i in  range(0,30): #len(df)):
#         bert = df['model'][i]
#         score = df[bert][i]
#         gpt_eval.append (evaluate(instr, article, score, answer))
#     results_df[bert] = gpt_eval

# %%
results_df = pd.DataFrame()
column_names = list(df.columns)

instr = "Decide if the following summary is fair with the corresponding article. Note that fairness means the summary should not have a distinct tone or angle and should present the information in a neutral manner without any bias."
answer = "Answer (yes or no)"
for model in column_names[2:]:
    gpt_eval = []
    for i in  range(0,30): #len(df)):
        article = df['article'][i]
        summary = df[model][i]
        gpt_eval.append (evaluate(instr, article, summary, answer))
    results_df[model] = gpt_eval

# %%
results_df
# Out:
#    sshleifer/distilbart-cnn-12-6
# 0                            Yes  \
# 1                            Yes
# 2                            Yes
# 3                            Yes
# 4                            Yes
# 5                            Yes
# 6                             No
# 7                             No
# 8                             No
# 9                            Yes
# 10                           Yes
# 11                           Yes
# 12                           Yes
# 13                            No
# 14                            No
# 15                           Yes
# 16                           Yes
# 17                           Yes
# 18                            No
# 19                           Yes
# 20                           Yes
# 21                           Yes
# 22                           Yes
# 23                           Yes
# 24                           Yes
# 25                           Yes
# 26                           Yes
# ...

# %%
file_path = "fairness_prompt_1-gpt.csv"
results_df.to_csv(file_path, index=False)

# %%
results_df_cot = pd.DataFrame()

instr = "Decide if the following summary is fair with the corresponding article. Note that fairness means the summary should not have a distinct tone or angle and should present the information in a neutral manner without any bias."
answer = "Explain your reasoning step by step then answer the question (yes or no)"
for model in column_names[2:]:
    gpt_eval = []
    for i in range(0, len(df)):
        article = df['article'][i]
        summary = df[model][i]
        gpt_eval.append (evaluate(instr, article, summary, answer))
    results_df_cot[model] = gpt_eval

# %%
results_df_cot

# %%
file_path = "fairness_prompt_2-gpt.csv"
results_df_cot.to_csv(file_path, index=False)

# %%
results_df_marks = pd.DataFrame()

instr = "Score the following summary given the corresponding article with respect to fairness from 0 to 1 where 1 means the most accurate. Note that fairness means the summary should not have a distinct tone or angle and should present the information in a neutral manner without any bias."
answer = "Points"
for model in column_names[2:]:
    gpt_eval = []
    for i in range(0, 30): #len(df)):
        article = df['article'][i]
        summary = df[model][i]
        gpt_eval.append (evaluate(instr, article, summary, answer))
    results_df_marks[model] = gpt_eval

# %%
results_df_marks

# %%
file_path = "fairness_prompt_3-gpt.csv"
results_df_marks.to_csv(file_path, index=False)
